# %%
import pandas as pd
# %matplotlib inline
import pylab as plt
import numpy as np
import scipy as sc
import scipy.stats

# %%
data = pd.read_csv('data/processed.csv')
data.head()
# Out:
#      campus  year                                school         city county  \
# 0  Berkeley  1994             ALBUQUERQUE ACADEMY320003  Albuquerque    NaN
# 1  Berkeley  1994             ALBUQUERQUE ACADEMY320003  Albuquerque    NaN
# 2  Berkeley  1994        AMERICAN SCHOOL IN JAPAN680400          NaN    NaN
# 3  Berkeley  1994        AMERICAN SCHOOL IN JAPAN680400          NaN    NaN
# 4  Berkeley  1994  BATON ROUGE MAGNET HIGH SCHOOL190179  Baton Rouge    NaN
#
#        region  is_international ethnicity  app_num  adm_num  enr_num  \
# 0  New Mexico             False       All     11.0      4.0      NaN
# 1  New Mexico             False     White      6.0      NaN      NaN
# 2       JAPAN              True       All     10.0      4.0      NaN
# 3       JAPAN              True     Asian      5.0      NaN      NaN
# 4   Louisiana             False       All      7.0      3.0      NaN
#
#     app_gpa  adm_gpa  enr_gpa
# 0  3.715455      NaN      NaN
# 1  3.715455      NaN      NaN
# ...

# %%
# data['yield'] = data['enr_num'] / data['adm_num']
gb = data.loc[(data['ethnicity']=='All') & (data['campus']=='Universitywide')].groupby("school")
series = []
i = 0
for name, group in gb:
    print(name)
    plt.figure()
    group[['app_num', 'adm_num', 'enr_num']].plot()
    if i > 10:
        break
    i += 1
# Out:
# 21ST CENTURY EXPERIMENTAL SCH694223
# A & M CONSOLIDATED HIGH SCHOOL441400
# A C DAVIS SENIOR HIGH SCHOOL481601
# A MACEO SMITH NEW TECH HS441742
# A N MCCALLUM HIGH SCHOOL440300
# ABERDEEN HIGH SCHOOL210000
# ABINGTON FRIENDS SCHOOL391915
# ABINGTON HIGH SCHOOL390000
# ABSEGAMI HIGH SCHOOL310759
# ABU DHABI INDIAN SCHOOL697045
# ABU DHABI INTERNATIONAL SCHOOL697006
# ACAD FOR CUL VIS TELE & PERF310451
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
